# %%
import cv2
import pytesseract
import numpy as np

# %%
import cv2
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

def preprocess_image(image_path):
    # Load the image
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError("Image not found or invalid image path.")

    # Convert to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply Gaussian blur
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)

    # Apply adaptive thresholding
    processed = cv2.adaptiveThreshold(
        blurred, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2
    )
    return processed

# %%
def recognize_text(image_path):
    # Preprocess the image
    processed_image = preprocess_image(image_path)

    # Perform OCR on the processed image
    text = pytesseract.image_to_string(processed_image, lang="eng")

    return text

# %%
from IPython.display import Image
Image(filename='logoscv.jpg')

# %%
def main():
    # Input image path
    image_path1 = "logoscv.jpg"  # Replace with your image path
    try:
        # Recognize text from the image
        recognized_text = recognize_text(image_path1)
        print("Recognized Text:")
        print(recognized_text)
    except ValueError as e:
        print(f"Error: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

if __name__ == "__main__":
    main()
# Out:
# Recognized Text:
# Cartier Honeywell
#
# CHANEL
#
# . LACOSTE
# Coots Rborabin
# BLL
# Nests
# Deloitte.
# . PHILIPS $suZUKI
# Ferrari
#
# Tamennt| TOYOTA
#
# GIVENCHY PRADA _ VERSACE

# %%
from IPython.display import Image
Image(filename='quotecv.jpeg')

# %%
image_path2 = "quotecv.jpeg"
text=recognize_text(image_path2)
print("Recognized Text:")
print(text)
# Out:
# Recognized Text:
# "MAKE TEXT
# STAND OUT FROM
# BACKGROUNDS 97 <<

# %%
from IPython.display import Image
Image(filename='wordscv.jpeg')

# %%
text=recognize_text("wordscv.jpeg")
print("Recognized Text:")
print(text)
# Out:
# Recognized Text:
# Om
#
# ‘All your messages:

# %%
from IPython.display import Image
Image(filename='linecv.png')

# %%
text=recognize_text("linecv.png")
print("Recognized Text:")
print(text)
# Out:
# Recognized Text:
# How to convert image
# to word document? a7
# v
#
# <!
#
# rm
#
# iF
#
# \
#
# *
